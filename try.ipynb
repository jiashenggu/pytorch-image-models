# %%
import timm
import torch
# from thop import profile
from ptflops import get_model_complexity_info
from pprint import pprint
import torch
import pdb
from torch import nn

# %%
model = timm.create_model('mobile_former_26m')
# Out:
# block: 12544, cnn-drop 0.0000, mlp-drop 0.0000
# block: 3136, cnn-drop 0.0000, mlp-drop 0.0000
# L2G: 2 heads, inp: 12, token: 128
# G2G: 4 heads
# use ffn
# G2L: 2 heads, inp: 12, token: 128
# block: 3136, cnn-drop 0.0000, mlp-drop 0.0000
# L2G: 2 heads, inp: 12, token: 128
# G2G: 4 heads
# use ffn
# G2L: 2 heads, inp: 24, token: 128
# block: 784, cnn-drop 0.0000, mlp-drop 0.0000
# L2G: 2 heads, inp: 24, token: 128
# G2G: 4 heads
# use ffn
# G2L: 2 heads, inp: 24, token: 128
# block: 784, cnn-drop 0.0000, mlp-drop 0.0000
# L2G: 2 heads, inp: 24, token: 128
# G2G: 4 heads
# use ffn
# G2L: 2 heads, inp: 48, token: 128
# block: 196, cnn-drop 0.0000, mlp-drop 0.0000
# L2G: 2 heads, inp: 48, token: 128
# G2G: 4 heads
# use ffn
# G2L: 2 heads, inp: 48, token: 128
# block: 196, cnn-drop 0.0000, mlp-drop 0.0000
# L2G: 2 heads, inp: 48, token: 128
# G2G: 4 heads
# use ffn
# G2L: 2 heads, inp: 64, token: 128
# block: 196, cnn-drop 0.0000, mlp-drop 0.0000
# L2G: 2 heads, inp: 64, token: 128
# G2G: 4 heads
# use ffn
# G2L: 2 heads, inp: 96, token: 128
# block: 49, cnn-drop 0.0000, mlp-drop 0.0000
# L2G: 2 heads, inp: 96, token: 128
# G2G: 4 heads
# use ffn
# G2L: 2 heads, inp: 96, token: 128
# L2G: 2 heads, inp: 96, token: 128
# MobileFormer(
#   (tokens): Embedding(3, 128)
#   (stem): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (features): Sequential(
#     (0): DnaBlock3(
#       (conv): Sequential(
#         (0): Conv2d(8, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): ChannelShuffle()
#         (4): Conv2d(24, 12, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (5): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): DnaBlock(
#       (conv1): Sequential(
#         (0): Conv2d(12, 36, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act1): DyReLU(
#         (act): Sequential()
#       )
#       (hyper1): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=72, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         (0): Conv2d(36, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=36, bias=False)
#         (1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         (act): Sequential()
#       )
#       (hyper2): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=72, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv3): Sequential(
#         (0): Conv2d(36, 12, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act3): DyReLU(
#         (act): Sequential()
#       )
#       (hyper3): Sequential()
#       (drop_path): DropPath(drop_prob=0.000)
#       (local_global): Local2Global(
#         (alpha): Sequential(
#           (0): Linear(in_features=128, out_features=12, bias=True)
#           (1): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (q): Linear(in_features=128, out_features=12, bias=True)
#         (proj): Linear(in_features=12, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         (ffn): Sequential(
#           (0): Linear(in_features=128, out_features=256, bias=True)
#           (1): GELU(approximate=none)
#           (2): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         (k): Linear(in_features=128, out_features=12, bias=True)
#         (proj): Linear(in_features=128, out_features=12, bias=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#     )
#     (2): DnaBlock3(
#       (conv1): Sequential(
#         (0): Conv2d(12, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=12, bias=False)
#         (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act1): DyReLU(
#         (act): Sequential()
#       )
#       (hyper1): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=144, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         (act): Sequential()
#       )
#       (conv3): Sequential(
#         (0): Conv2d(24, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act3): DyReLU(
#         (act): Sequential()
#       )
#       (hyper3): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=192, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv4): Sequential(
#         (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act4): DyReLU(
#         (act): Sequential()
#       )
#       (hyper4): Sequential()
#       (drop_path): DropPath(drop_prob=0.000)
#       (local_global): Local2Global(
#         (alpha): Sequential(
#           (0): Linear(in_features=128, out_features=12, bias=True)
#           (1): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (q): Linear(in_features=128, out_features=12, bias=True)
#         (proj): Linear(in_features=12, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         (ffn): Sequential(
#           (0): Linear(in_features=128, out_features=256, bias=True)
#           (1): GELU(approximate=none)
#           (2): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         (k): Linear(in_features=128, out_features=24, bias=True)
#         (proj): Linear(in_features=128, out_features=24, bias=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#     )
#     (3): DnaBlock(
#       (conv1): Sequential(
#         (0): Conv2d(24, 72, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act1): DyReLU(
#         (act): Sequential()
#       )
#       (hyper1): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=144, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#         (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         (act): Sequential()
#       )
#       (hyper2): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=144, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv3): Sequential(
#         (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act3): DyReLU(
#         (act): Sequential()
#       )
#       (hyper3): Sequential()
#       (drop_path): DropPath(drop_prob=0.000)
#       (local_global): Local2Global(
#         (alpha): Sequential(
#           (0): Linear(in_features=128, out_features=24, bias=True)
#           (1): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (q): Linear(in_features=128, out_features=24, bias=True)
#         (proj): Linear(in_features=24, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         (ffn): Sequential(
#           (0): Linear(in_features=128, out_features=256, bias=True)
#           (1): GELU(approximate=none)
#           (2): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         (k): Linear(in_features=128, out_features=24, bias=True)
#         (proj): Linear(in_features=128, out_features=24, bias=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#     )
#     (4): DnaBlock3(
#       (conv1): Sequential(
#         (0): Conv2d(24, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act1): DyReLU(
#         (act): Sequential()
#       )
#       (hyper1): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=288, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         (0): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         (act): Sequential()
#       )
#       (conv3): Sequential(
#         (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act3): DyReLU(
#         (act): Sequential()
#       )
#       (hyper3): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=384, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv4): Sequential(
#         (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act4): DyReLU(
#         (act): Sequential()
#       )
#       (hyper4): Sequential()
#       (drop_path): DropPath(drop_prob=0.000)
#       (local_global): Local2Global(
#         (alpha): Sequential(
#           (0): Linear(in_features=128, out_features=24, bias=True)
#           (1): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (q): Linear(in_features=128, out_features=24, bias=True)
#         (proj): Linear(in_features=24, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         (ffn): Sequential(
#           (0): Linear(in_features=128, out_features=256, bias=True)
#           (1): GELU(approximate=none)
#           (2): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         (k): Linear(in_features=128, out_features=48, bias=True)
#         (proj): Linear(in_features=128, out_features=48, bias=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#     )
#     (5): DnaBlock(
#       (conv1): Sequential(
#         (0): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act1): DyReLU(
#         (act): Sequential()
#       )
#       (hyper1): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=384, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         (act): Sequential()
#       )
#       (hyper2): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=384, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv3): Sequential(
#         (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act3): DyReLU(
#         (act): Sequential()
#       )
#       (hyper3): Sequential()
#       (drop_path): DropPath(drop_prob=0.000)
#       (local_global): Local2Global(
#         (alpha): Sequential(
#           (0): Linear(in_features=128, out_features=48, bias=True)
#           (1): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (q): Linear(in_features=128, out_features=48, bias=True)
#         (proj): Linear(in_features=48, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         (ffn): Sequential(
#           (0): Linear(in_features=128, out_features=256, bias=True)
#           (1): GELU(approximate=none)
#           (2): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         (k): Linear(in_features=128, out_features=48, bias=True)
#         (proj): Linear(in_features=128, out_features=48, bias=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#     )
#     (6): DnaBlock(
#       (conv1): Sequential(
#         (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act1): DyReLU(
#         (act): Sequential()
#       )
#       (hyper1): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=576, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#         (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         (act): Sequential()
#       )
#       (hyper2): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=576, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv3): Sequential(
#         (0): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act3): DyReLU(
#         (act): Sequential()
#       )
#       (hyper3): Sequential()
#       (drop_path): DropPath(drop_prob=0.000)
#       (local_global): Local2Global(
#         (alpha): Sequential(
#           (0): Linear(in_features=128, out_features=48, bias=True)
#           (1): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (q): Linear(in_features=128, out_features=48, bias=True)
#         (proj): Linear(in_features=48, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         (ffn): Sequential(
#           (0): Linear(in_features=128, out_features=256, bias=True)
#           (1): GELU(approximate=none)
#           (2): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         (k): Linear(in_features=128, out_features=64, bias=True)
#         (proj): Linear(in_features=128, out_features=64, bias=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#     )
#     (7): DnaBlock3(
#       (conv1): Sequential(
#         (0): Conv2d(64, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act1): DyReLU(
#         (act): Sequential()
#       )
#       (hyper1): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=768, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         (0): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         (act): Sequential()
#       )
#       (conv3): Sequential(
#         (0): Conv2d(96, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act3): DyReLU(
#         (act): Sequential()
#       )
#       (hyper3): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=768, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv4): Sequential(
#         (0): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act4): DyReLU(
#         (act): Sequential()
#       )
#       (hyper4): Sequential()
#       (drop_path): DropPath(drop_prob=0.000)
#       (local_global): Local2Global(
#         (alpha): Sequential(
#           (0): Linear(in_features=128, out_features=64, bias=True)
#           (1): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (q): Linear(in_features=128, out_features=64, bias=True)
#         (proj): Linear(in_features=64, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         (ffn): Sequential(
#           (0): Linear(in_features=128, out_features=256, bias=True)
#           (1): GELU(approximate=none)
#           (2): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         (k): Linear(in_features=128, out_features=96, bias=True)
#         (proj): Linear(in_features=128, out_features=96, bias=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#     )
#     (8): DnaBlock(
#       (conv1): Sequential(
#         (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act1): DyReLU(
#         (act): Sequential()
#       )
#       (hyper1): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=1152, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         (act): Sequential()
#       )
#       (hyper2): HyperFunc(
#         (hyper): Sequential(
#           (0): Linear(in_features=128, out_features=32, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=1152, bias=True)
#           (3): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#       )
#       (conv3): Sequential(
#         (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle()
#       )
#       (act3): DyReLU(
#         (act): Sequential()
#       )
#       (hyper3): Sequential()
#       (drop_path): DropPath(drop_prob=0.000)
#       (local_global): Local2Global(
#         (alpha): Sequential(
#           (0): Linear(in_features=128, out_features=96, bias=True)
#           (1): h_sigmoid(
#             (relu): ReLU6(inplace=True)
#           )
#         )
#         (q): Linear(in_features=128, out_features=96, bias=True)
#         (proj): Linear(in_features=96, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         (ffn): Sequential(
#           (0): Linear(in_features=128, out_features=256, bias=True)
#           (1): GELU(approximate=none)
#           (2): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         (k): Linear(in_features=128, out_features=96, bias=True)
#         (proj): Linear(in_features=128, out_features=96, bias=True)
#         (drop_path): DropPath(drop_prob=0.000)
#       )
#     )
#   )
#   (local_global): Local2Global(
#     (alpha): Sequential(
#       (0): Linear(in_features=128, out_features=96, bias=True)
#       (1): h_sigmoid(
#         (relu): ReLU6(inplace=True)
#       )
#     )
#     (q): Linear(in_features=128, out_features=96, bias=True)
#     (proj): Linear(in_features=96, out_features=128, bias=True)
#     (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (drop_path): DropPath(drop_prob=0.000)
#   )
#   (classifier): MergeClassifier(
#     (conv): Sequential(
#       (0): ChannelShuffle()
#       (1): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#       (2): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act): DyReLU(
#       (act): ReLU6(inplace=True)
#     )
#     (hyper): Sequential()
#     (avgpool): Sequential(
#       (0): AdaptiveAvgPool2d(output_size=(1, 1))
#       (1): h_swish(
#         (sigmoid): h_sigmoid(
#           (relu): ReLU6(inplace=True)
#         )
#       )
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=704, out_features=1024, bias=True)
#       (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid(
#           (relu): ReLU6(inplace=True)
#         )
#       )
#     )
#     (classifier): Sequential(
#       (0): Dropout(p=0.0, inplace=False)
#       (1): Linear(in_features=1024, out_features=1000, bias=True)
#     )
#   )
# )

# %%
input = torch.randn(1, 3, 224, 224)
macs, params = get_model_complexity_info(model, (3, 224, 224), as_strings=True,
                                           print_per_layer_stat=True, verbose=True)
print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# Warning: module Embedding is treated as a zero-op.
# Warning: module ChannelShuffle is treated as a zero-op.
# Warning: module DnaBlock3 is treated as a zero-op.
# Warning: module DyReLU is treated as a zero-op.
# Warning: module h_sigmoid is treated as a zero-op.
# Warning: module HyperFunc is treated as a zero-op.
# Warning: module DropPath is treated as a zero-op.
# Warning: module LayerNorm is treated as a zero-op.
# Warning: module Local2Global is treated as a zero-op.
# Warning: module GlobalBlock is treated as a zero-op.
# Warning: module Global2Local is treated as a zero-op.
# Warning: module DnaBlock is treated as a zero-op.
# Warning: module h_swish is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Warning: module MergeClassifier is treated as a zero-op.
# Warning: module MobileFormer is treated as a zero-op.
# MobileFormer(
#   3.23 M, 99.790% Params, 24.6 MMac, 100.000% MACs,
#   (tokens): Embedding(0, 0.000% Params, 0.0 Mac, 0.000% MACs, 3, 128)
#   (stem): Sequential(
#     232, 0.007% Params, 3.01 MMac, 12.238% MACs,
#     (0): Conv2d(216, 0.007% Params, 2.71 MMac, 11.014% MACs, 3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, 0.000% Params, 200.7 KMac, 0.816% MACs, 8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(0, 0.000% Params, 100.35 KMac, 0.408% MACs, inplace=True)
#   )
#   (features): Sequential(
#     1.42 M, 44.069% Params, 18.94 MMac, 76.981% MACs,
#     (0): DnaBlock3(
#       360, 0.011% Params, 1.2 MMac, 4.895% MACs,
#       (conv): Sequential(
#         360, 0.011% Params, 1.2 MMac, 4.895% MACs,
#         (0): Conv2d(216, 0.007% Params, 677.38 KMac, 2.754% MACs, 8, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#         (1): BatchNorm2d(48, 0.001% Params, 150.53 KMac, 0.612% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.306% MACs, inplace=True)
#         (3): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         (4): Conv2d(72, 0.002% Params, 225.79 KMac, 0.918% MACs, 24, 12, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (5): BatchNorm2d(24, 0.001% Params, 75.26 KMac, 0.306% MACs, 12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): DnaBlock(
#       120.52 k, 3.728% Params, 2.55 MMac, 10.378% MACs,
#       (conv1): Sequential(
#         180, 0.006% Params, 564.48 KMac, 2.295% MACs,
#         (0): Conv2d(108, 0.003% Params, 338.69 KMac, 1.377% MACs, 12, 36, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(72, 0.002% Params, 225.79 KMac, 0.918% MACs, 36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act1): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper1): HyperFunc(
#         6.5 k, 0.201% Params, 6.61 KMac, 0.027% MACs,
#         (hyper): Sequential(
#           6.5 k, 0.201% Params, 6.61 KMac, 0.027% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(2.38 k, 0.073% Params, 2.38 KMac, 0.010% MACs, in_features=32, out_features=72, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 72.0 Mac, 0.000% MACs,
#             (relu): ReLU6(0, 0.000% Params, 72.0 Mac, 0.000% MACs, inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         396, 0.012% Params, 1.24 MMac, 5.048% MACs,
#         (0): Conv2d(324, 0.010% Params, 1.02 MMac, 4.130% MACs, 36, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=36, bias=False)
#         (1): BatchNorm2d(72, 0.002% Params, 225.79 KMac, 0.918% MACs, 36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper2): HyperFunc(
#         6.5 k, 0.201% Params, 6.61 KMac, 0.027% MACs,
#         (hyper): Sequential(
#           6.5 k, 0.201% Params, 6.61 KMac, 0.027% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(2.38 k, 0.073% Params, 2.38 KMac, 0.010% MACs, in_features=32, out_features=72, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 72.0 Mac, 0.000% MACs,
#             (relu): ReLU6(0, 0.000% Params, 72.0 Mac, 0.000% MACs, inplace=True)
#           )
#         )
#       )
#       (conv3): Sequential(
#         132, 0.004% Params, 413.95 KMac, 1.683% MACs,
#         (0): Conv2d(108, 0.003% Params, 338.69 KMac, 1.377% MACs, 36, 12, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(24, 0.001% Params, 75.26 KMac, 0.306% MACs, 12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act3): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper3): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       (local_global): Local2Global(
#         4.76 k, 0.147% Params, 14.01 KMac, 0.057% MACs,
#         (alpha): Sequential(
#           1.55 k, 0.048% Params, 4.66 KMac, 0.019% MACs,
#           (0): Linear(1.55 k, 0.048% Params, 4.62 KMac, 0.019% MACs, in_features=128, out_features=12, bias=True)
#           (1): h_sigmoid(
#             0, 0.000% Params, 36.0 Mac, 0.000% MACs,
#             (relu): ReLU6(0, 0.000% Params, 36.0 Mac, 0.000% MACs, inplace=True)
#           )
#         )
#         (q): Linear(1.55 k, 0.048% Params, 4.62 KMac, 0.019% MACs, in_features=128, out_features=12, bias=True)
#         (proj): Linear(1.66 k, 0.051% Params, 4.74 KMac, 0.019% MACs, in_features=12, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         98.94 k, 3.061% Params, 296.32 KMac, 1.205% MACs,
#         (ffn): Sequential(
#           65.92 k, 2.039% Params, 197.76 KMac, 0.804% MACs,
#           (0): Linear(33.02 k, 1.022% Params, 98.56 KMac, 0.401% MACs, in_features=128, out_features=256, bias=True)
#           (1): GELU(0, 0.000% Params, 768.0 Mac, 0.003% MACs, approximate=none)
#           (2): Linear(32.9 k, 1.018% Params, 98.43 KMac, 0.400% MACs, in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         3.1 k, 0.096% Params, 9.24 KMac, 0.038% MACs,
#         (k): Linear(1.55 k, 0.048% Params, 4.62 KMac, 0.019% MACs, in_features=128, out_features=12, bias=True)
#         (proj): Linear(1.55 k, 0.048% Params, 4.62 KMac, 0.019% MACs, in_features=128, out_features=12, bias=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#     )
#     (2): DnaBlock3(
#       132.19 k, 4.089% Params, 2.66 MMac, 10.825% MACs,
#       (conv1): Sequential(
#         792, 0.024% Params, 620.93 KMac, 2.524% MACs,
#         (0): Conv2d(648, 0.020% Params, 508.03 KMac, 2.065% MACs, 12, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=12, bias=False)
#         (1): BatchNorm2d(144, 0.004% Params, 112.9 KMac, 0.459% MACs, 72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act1): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper1): HyperFunc(
#         8.88 k, 0.275% Params, 9.06 KMac, 0.037% MACs,
#         (hyper): Sequential(
#           8.88 k, 0.275% Params, 9.06 KMac, 0.037% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(4.75 k, 0.147% Params, 4.75 KMac, 0.019% MACs, in_features=32, out_features=144, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 144.0 Mac, 0.001% MACs,
#             (relu): ReLU6(0, 0.000% Params, 144.0 Mac, 0.001% MACs, inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         480, 0.015% Params, 376.32 KMac, 1.530% MACs,
#         (0): Conv2d(432, 0.013% Params, 338.69 KMac, 1.377% MACs, 72, 24, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(48, 0.001% Params, 37.63 KMac, 0.153% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (conv3): Sequential(
#         1.06 k, 0.033% Params, 827.9 KMac, 3.365% MACs,
#         (0): Conv2d(864, 0.027% Params, 677.38 KMac, 2.754% MACs, 24, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(192, 0.006% Params, 150.53 KMac, 0.612% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act3): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper3): HyperFunc(
#         10.46 k, 0.324% Params, 10.69 KMac, 0.043% MACs,
#         (hyper): Sequential(
#           10.46 k, 0.324% Params, 10.69 KMac, 0.043% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(6.34 k, 0.196% Params, 6.34 KMac, 0.026% MACs, in_features=32, out_features=192, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 192.0 Mac, 0.001% MACs,
#             (relu): ReLU6(0, 0.000% Params, 192.0 Mac, 0.001% MACs, inplace=True)
#           )
#         )
#       )
#       (conv4): Sequential(
#         624, 0.019% Params, 489.22 KMac, 1.989% MACs,
#         (0): Conv2d(576, 0.018% Params, 451.58 KMac, 1.836% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(48, 0.001% Params, 37.63 KMac, 0.153% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act4): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper4): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       (local_global): Local2Global(
#         4.76 k, 0.147% Params, 14.01 KMac, 0.057% MACs,
#         (alpha): Sequential(
#           1.55 k, 0.048% Params, 4.66 KMac, 0.019% MACs,
#           (0): Linear(1.55 k, 0.048% Params, 4.62 KMac, 0.019% MACs, in_features=128, out_features=12, bias=True)
#           (1): h_sigmoid(
#             0, 0.000% Params, 36.0 Mac, 0.000% MACs,
#             (relu): ReLU6(0, 0.000% Params, 36.0 Mac, 0.000% MACs, inplace=True)
#           )
#         )
#         (q): Linear(1.55 k, 0.048% Params, 4.62 KMac, 0.019% MACs, in_features=128, out_features=12, bias=True)
#         (proj): Linear(1.66 k, 0.051% Params, 4.74 KMac, 0.019% MACs, in_features=12, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         98.94 k, 3.061% Params, 296.32 KMac, 1.205% MACs,
#         (ffn): Sequential(
#           65.92 k, 2.039% Params, 197.76 KMac, 0.804% MACs,
#           (0): Linear(33.02 k, 1.022% Params, 98.56 KMac, 0.401% MACs, in_features=128, out_features=256, bias=True)
#           (1): GELU(0, 0.000% Params, 768.0 Mac, 0.003% MACs, approximate=none)
#           (2): Linear(32.9 k, 1.018% Params, 98.43 KMac, 0.400% MACs, in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         6.19 k, 0.192% Params, 18.48 KMac, 0.075% MACs,
#         (k): Linear(3.1 k, 0.096% Params, 9.24 KMac, 0.038% MACs, in_features=128, out_features=24, bias=True)
#         (proj): Linear(3.1 k, 0.096% Params, 9.24 KMac, 0.038% MACs, in_features=128, out_features=24, bias=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#     )
#     (3): DnaBlock(
#       134.14 k, 4.149% Params, 1.81 MMac, 7.356% MACs,
#       (conv1): Sequential(
#         576, 0.018% Params, 451.58 KMac, 1.836% MACs,
#         (0): Conv2d(432, 0.013% Params, 338.69 KMac, 1.377% MACs, 24, 72, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(144, 0.004% Params, 112.9 KMac, 0.459% MACs, 72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act1): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper1): HyperFunc(
#         8.88 k, 0.275% Params, 9.06 KMac, 0.037% MACs,
#         (hyper): Sequential(
#           8.88 k, 0.275% Params, 9.06 KMac, 0.037% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(4.75 k, 0.147% Params, 4.75 KMac, 0.019% MACs, in_features=32, out_features=144, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 144.0 Mac, 0.001% MACs,
#             (relu): ReLU6(0, 0.000% Params, 144.0 Mac, 0.001% MACs, inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         792, 0.024% Params, 620.93 KMac, 2.524% MACs,
#         (0): Conv2d(648, 0.020% Params, 508.03 KMac, 2.065% MACs, 72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#         (1): BatchNorm2d(144, 0.004% Params, 112.9 KMac, 0.459% MACs, 72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper2): HyperFunc(
#         8.88 k, 0.275% Params, 9.06 KMac, 0.037% MACs,
#         (hyper): Sequential(
#           8.88 k, 0.275% Params, 9.06 KMac, 0.037% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(4.75 k, 0.147% Params, 4.75 KMac, 0.019% MACs, in_features=32, out_features=144, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 144.0 Mac, 0.001% MACs,
#             (relu): ReLU6(0, 0.000% Params, 144.0 Mac, 0.001% MACs, inplace=True)
#           )
#         )
#       )
#       (conv3): Sequential(
#         480, 0.015% Params, 376.32 KMac, 1.530% MACs,
#         (0): Conv2d(432, 0.013% Params, 338.69 KMac, 1.377% MACs, 72, 24, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(48, 0.001% Params, 37.63 KMac, 0.153% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act3): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper3): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       (local_global): Local2Global(
#         9.39 k, 0.291% Params, 27.9 KMac, 0.113% MACs,
#         (alpha): Sequential(
#           3.1 k, 0.096% Params, 9.31 KMac, 0.038% MACs,
#           (0): Linear(3.1 k, 0.096% Params, 9.24 KMac, 0.038% MACs, in_features=128, out_features=24, bias=True)
#           (1): h_sigmoid(
#             0, 0.000% Params, 72.0 Mac, 0.000% MACs,
#             (relu): ReLU6(0, 0.000% Params, 72.0 Mac, 0.000% MACs, inplace=True)
#           )
#         )
#         (q): Linear(3.1 k, 0.096% Params, 9.24 KMac, 0.038% MACs, in_features=128, out_features=24, bias=True)
#         (proj): Linear(3.2 k, 0.099% Params, 9.34 KMac, 0.038% MACs, in_features=24, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         98.94 k, 3.061% Params, 296.32 KMac, 1.205% MACs,
#         (ffn): Sequential(
#           65.92 k, 2.039% Params, 197.76 KMac, 0.804% MACs,
#           (0): Linear(33.02 k, 1.022% Params, 98.56 KMac, 0.401% MACs, in_features=128, out_features=256, bias=True)
#           (1): GELU(0, 0.000% Params, 768.0 Mac, 0.003% MACs, approximate=none)
#           (2): Linear(32.9 k, 1.018% Params, 98.43 KMac, 0.400% MACs, in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         6.19 k, 0.192% Params, 18.48 KMac, 0.075% MACs,
#         (k): Linear(3.1 k, 0.096% Params, 9.24 KMac, 0.038% MACs, in_features=128, out_features=24, bias=True)
#         (proj): Linear(3.1 k, 0.096% Params, 9.24 KMac, 0.038% MACs, in_features=128, out_features=24, bias=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#     )
#     (4): DnaBlock3(
#       159.07 k, 4.921% Params, 1.94 MMac, 7.905% MACs,
#       (conv1): Sequential(
#         1.58 k, 0.049% Params, 310.46 KMac, 1.262% MACs,
#         (0): Conv2d(1.3 k, 0.040% Params, 254.02 KMac, 1.033% MACs, 24, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(288, 0.009% Params, 56.45 KMac, 0.229% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act1): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper1): HyperFunc(
#         13.63 k, 0.422% Params, 13.95 KMac, 0.057% MACs,
#         (hyper): Sequential(
#           13.63 k, 0.422% Params, 13.95 KMac, 0.057% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(9.5 k, 0.294% Params, 9.5 KMac, 0.039% MACs, in_features=32, out_features=288, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 288.0 Mac, 0.001% MACs,
#             (relu): ReLU6(0, 0.000% Params, 288.0 Mac, 0.001% MACs, inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         1.82 k, 0.056% Params, 357.5 KMac, 1.453% MACs,
#         (0): Conv2d(1.73 k, 0.053% Params, 338.69 KMac, 1.377% MACs, 144, 48, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(96, 0.003% Params, 18.82 KMac, 0.076% MACs, 48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (conv3): Sequential(
#         2.11 k, 0.065% Params, 413.95 KMac, 1.683% MACs,
#         (0): Conv2d(1.73 k, 0.053% Params, 338.69 KMac, 1.377% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#         (1): BatchNorm2d(384, 0.012% Params, 75.26 KMac, 0.306% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act3): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper3): HyperFunc(
#         16.8 k, 0.520% Params, 17.22 KMac, 0.070% MACs,
#         (hyper): Sequential(
#           16.8 k, 0.520% Params, 17.22 KMac, 0.070% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(12.67 k, 0.392% Params, 12.67 KMac, 0.052% MACs, in_features=32, out_features=384, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 384.0 Mac, 0.002% MACs,
#             (relu): ReLU6(0, 0.000% Params, 384.0 Mac, 0.002% MACs, inplace=True)
#           )
#         )
#       )
#       (conv4): Sequential(
#         2.4 k, 0.074% Params, 470.4 KMac, 1.912% MACs,
#         (0): Conv2d(2.3 k, 0.071% Params, 451.58 KMac, 1.836% MACs, 192, 48, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(96, 0.003% Params, 18.82 KMac, 0.076% MACs, 48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act4): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper4): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       (local_global): Local2Global(
#         9.39 k, 0.291% Params, 27.9 KMac, 0.113% MACs,
#         (alpha): Sequential(
#           3.1 k, 0.096% Params, 9.31 KMac, 0.038% MACs,
#           (0): Linear(3.1 k, 0.096% Params, 9.24 KMac, 0.038% MACs, in_features=128, out_features=24, bias=True)
#           (1): h_sigmoid(
#             0, 0.000% Params, 72.0 Mac, 0.000% MACs,
#             (relu): ReLU6(0, 0.000% Params, 72.0 Mac, 0.000% MACs, inplace=True)
#           )
#         )
#         (q): Linear(3.1 k, 0.096% Params, 9.24 KMac, 0.038% MACs, in_features=128, out_features=24, bias=True)
#         (proj): Linear(3.2 k, 0.099% Params, 9.34 KMac, 0.038% MACs, in_features=24, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         98.94 k, 3.061% Params, 296.32 KMac, 1.205% MACs,
#         (ffn): Sequential(
#           65.92 k, 2.039% Params, 197.76 KMac, 0.804% MACs,
#           (0): Linear(33.02 k, 1.022% Params, 98.56 KMac, 0.401% MACs, in_features=128, out_features=256, bias=True)
#           (1): GELU(0, 0.000% Params, 768.0 Mac, 0.003% MACs, approximate=none)
#           (2): Linear(32.9 k, 1.018% Params, 98.43 KMac, 0.400% MACs, in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         12.38 k, 0.383% Params, 36.96 KMac, 0.150% MACs,
#         (k): Linear(6.19 k, 0.192% Params, 18.48 KMac, 0.075% MACs, in_features=128, out_features=48, bias=True)
#         (proj): Linear(6.19 k, 0.192% Params, 18.48 KMac, 0.075% MACs, in_features=128, out_features=48, bias=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#     )
#     (5): DnaBlock(
#       170.78 k, 5.283% Params, 1.83 MMac, 7.458% MACs,
#       (conv1): Sequential(
#         2.69 k, 0.083% Params, 526.85 KMac, 2.142% MACs,
#         (0): Conv2d(2.3 k, 0.071% Params, 451.58 KMac, 1.836% MACs, 48, 192, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(384, 0.012% Params, 75.26 KMac, 0.306% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act1): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper1): HyperFunc(
#         16.8 k, 0.520% Params, 17.22 KMac, 0.070% MACs,
#         (hyper): Sequential(
#           16.8 k, 0.520% Params, 17.22 KMac, 0.070% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(12.67 k, 0.392% Params, 12.67 KMac, 0.052% MACs, in_features=32, out_features=384, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 384.0 Mac, 0.002% MACs,
#             (relu): ReLU6(0, 0.000% Params, 384.0 Mac, 0.002% MACs, inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         2.11 k, 0.065% Params, 413.95 KMac, 1.683% MACs,
#         (0): Conv2d(1.73 k, 0.053% Params, 338.69 KMac, 1.377% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (1): BatchNorm2d(384, 0.012% Params, 75.26 KMac, 0.306% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper2): HyperFunc(
#         16.8 k, 0.520% Params, 17.22 KMac, 0.070% MACs,
#         (hyper): Sequential(
#           16.8 k, 0.520% Params, 17.22 KMac, 0.070% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(12.67 k, 0.392% Params, 12.67 KMac, 0.052% MACs, in_features=32, out_features=384, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 384.0 Mac, 0.002% MACs,
#             (relu): ReLU6(0, 0.000% Params, 384.0 Mac, 0.002% MACs, inplace=True)
#           )
#         )
#       )
#       (conv3): Sequential(
#         2.4 k, 0.074% Params, 470.4 KMac, 1.912% MACs,
#         (0): Conv2d(2.3 k, 0.071% Params, 451.58 KMac, 1.836% MACs, 192, 48, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(96, 0.003% Params, 18.82 KMac, 0.076% MACs, 48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act3): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper3): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       (local_global): Local2Global(
#         18.66 k, 0.577% Params, 55.66 KMac, 0.226% MACs,
#         (alpha): Sequential(
#           6.19 k, 0.192% Params, 18.62 KMac, 0.076% MACs,
#           (0): Linear(6.19 k, 0.192% Params, 18.48 KMac, 0.075% MACs, in_features=128, out_features=48, bias=True)
#           (1): h_sigmoid(
#             0, 0.000% Params, 144.0 Mac, 0.001% MACs,
#             (relu): ReLU6(0, 0.000% Params, 144.0 Mac, 0.001% MACs, inplace=True)
#           )
#         )
#         (q): Linear(6.19 k, 0.192% Params, 18.48 KMac, 0.075% MACs, in_features=128, out_features=48, bias=True)
#         (proj): Linear(6.27 k, 0.194% Params, 18.56 KMac, 0.075% MACs, in_features=48, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         98.94 k, 3.061% Params, 296.32 KMac, 1.205% MACs,
#         (ffn): Sequential(
#           65.92 k, 2.039% Params, 197.76 KMac, 0.804% MACs,
#           (0): Linear(33.02 k, 1.022% Params, 98.56 KMac, 0.401% MACs, in_features=128, out_features=256, bias=True)
#           (1): GELU(0, 0.000% Params, 768.0 Mac, 0.003% MACs, approximate=none)
#           (2): Linear(32.9 k, 1.018% Params, 98.43 KMac, 0.400% MACs, in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         12.38 k, 0.383% Params, 36.96 KMac, 0.150% MACs,
#         (k): Linear(6.19 k, 0.192% Params, 18.48 KMac, 0.075% MACs, in_features=128, out_features=48, bias=True)
#         (proj): Linear(6.19 k, 0.192% Params, 18.48 KMac, 0.075% MACs, in_features=128, out_features=48, bias=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#     )
#     (6): DnaBlock(
#       192.32 k, 5.949% Params, 2.79 MMac, 11.334% MACs,
#       (conv1): Sequential(
#         4.03 k, 0.125% Params, 790.27 KMac, 3.212% MACs,
#         (0): Conv2d(3.46 k, 0.107% Params, 677.38 KMac, 2.754% MACs, 48, 288, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(576, 0.018% Params, 112.9 KMac, 0.459% MACs, 288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act1): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper1): HyperFunc(
#         23.14 k, 0.716% Params, 23.74 KMac, 0.097% MACs,
#         (hyper): Sequential(
#           23.14 k, 0.716% Params, 23.74 KMac, 0.097% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(19.01 k, 0.588% Params, 19.01 KMac, 0.077% MACs, in_features=32, out_features=576, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 576.0 Mac, 0.002% MACs,
#             (relu): ReLU6(0, 0.000% Params, 576.0 Mac, 0.002% MACs, inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         3.17 k, 0.098% Params, 620.93 KMac, 2.524% MACs,
#         (0): Conv2d(2.59 k, 0.080% Params, 508.03 KMac, 2.065% MACs, 288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#         (1): BatchNorm2d(576, 0.018% Params, 112.9 KMac, 0.459% MACs, 288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper2): HyperFunc(
#         23.14 k, 0.716% Params, 23.74 KMac, 0.097% MACs,
#         (hyper): Sequential(
#           23.14 k, 0.716% Params, 23.74 KMac, 0.097% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(19.01 k, 0.588% Params, 19.01 KMac, 0.077% MACs, in_features=32, out_features=576, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 576.0 Mac, 0.002% MACs,
#             (relu): ReLU6(0, 0.000% Params, 576.0 Mac, 0.002% MACs, inplace=True)
#           )
#         )
#       )
#       (conv3): Sequential(
#         4.74 k, 0.146% Params, 928.26 KMac, 3.773% MACs,
#         (0): Conv2d(4.61 k, 0.143% Params, 903.17 KMac, 3.671% MACs, 288, 64, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(128, 0.004% Params, 25.09 KMac, 0.102% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act3): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper3): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       (local_global): Local2Global(
#         18.66 k, 0.577% Params, 55.66 KMac, 0.226% MACs,
#         (alpha): Sequential(
#           6.19 k, 0.192% Params, 18.62 KMac, 0.076% MACs,
#           (0): Linear(6.19 k, 0.192% Params, 18.48 KMac, 0.075% MACs, in_features=128, out_features=48, bias=True)
#           (1): h_sigmoid(
#             0, 0.000% Params, 144.0 Mac, 0.001% MACs,
#             (relu): ReLU6(0, 0.000% Params, 144.0 Mac, 0.001% MACs, inplace=True)
#           )
#         )
#         (q): Linear(6.19 k, 0.192% Params, 18.48 KMac, 0.075% MACs, in_features=128, out_features=48, bias=True)
#         (proj): Linear(6.27 k, 0.194% Params, 18.56 KMac, 0.075% MACs, in_features=48, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         98.94 k, 3.061% Params, 296.32 KMac, 1.205% MACs,
#         (ffn): Sequential(
#           65.92 k, 2.039% Params, 197.76 KMac, 0.804% MACs,
#           (0): Linear(33.02 k, 1.022% Params, 98.56 KMac, 0.401% MACs, in_features=128, out_features=256, bias=True)
#           (1): GELU(0, 0.000% Params, 768.0 Mac, 0.003% MACs, approximate=none)
#           (2): Linear(32.9 k, 1.018% Params, 98.43 KMac, 0.400% MACs, in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs,
#         (k): Linear(8.26 k, 0.255% Params, 24.64 KMac, 0.100% MACs, in_features=128, out_features=64, bias=True)
#         (proj): Linear(8.26 k, 0.255% Params, 24.64 KMac, 0.100% MACs, in_features=128, out_features=64, bias=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#     )
#     (7): DnaBlock3(
#       234.75 k, 7.262% Params, 1.84 MMac, 7.483% MACs,
#       (conv1): Sequential(
#         4.22 k, 0.131% Params, 206.98 KMac, 0.841% MACs,
#         (0): Conv2d(3.46 k, 0.107% Params, 169.34 KMac, 0.688% MACs, 64, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#         (1): BatchNorm2d(768, 0.024% Params, 37.63 KMac, 0.153% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act1): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper1): HyperFunc(
#         29.47 k, 0.912% Params, 30.27 KMac, 0.123% MACs,
#         (hyper): Sequential(
#           29.47 k, 0.912% Params, 30.27 KMac, 0.123% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(25.34 k, 0.784% Params, 25.34 KMac, 0.103% MACs, in_features=32, out_features=768, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 768.0 Mac, 0.003% MACs,
#             (relu): ReLU6(0, 0.000% Params, 768.0 Mac, 0.003% MACs, inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         9.41 k, 0.291% Params, 460.99 KMac, 1.874% MACs,
#         (0): Conv2d(9.22 k, 0.285% Params, 451.58 KMac, 1.836% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(192, 0.006% Params, 9.41 KMac, 0.038% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (conv3): Sequential(
#         4.22 k, 0.131% Params, 206.98 KMac, 0.841% MACs,
#         (0): Conv2d(3.46 k, 0.107% Params, 169.34 KMac, 0.688% MACs, 96, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#         (1): BatchNorm2d(768, 0.024% Params, 37.63 KMac, 0.153% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act3): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper3): HyperFunc(
#         29.47 k, 0.912% Params, 30.27 KMac, 0.123% MACs,
#         (hyper): Sequential(
#           29.47 k, 0.912% Params, 30.27 KMac, 0.123% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(25.34 k, 0.784% Params, 25.34 KMac, 0.103% MACs, in_features=32, out_features=768, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 768.0 Mac, 0.003% MACs,
#             (relu): ReLU6(0, 0.000% Params, 768.0 Mac, 0.003% MACs, inplace=True)
#           )
#         )
#       )
#       (conv4): Sequential(
#         9.41 k, 0.291% Params, 460.99 KMac, 1.874% MACs,
#         (0): Conv2d(9.22 k, 0.285% Params, 451.58 KMac, 1.836% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(192, 0.006% Params, 9.41 KMac, 0.038% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act4): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper4): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       (local_global): Local2Global(
#         24.83 k, 0.768% Params, 74.18 KMac, 0.302% MACs,
#         (alpha): Sequential(
#           8.26 k, 0.255% Params, 24.83 KMac, 0.101% MACs,
#           (0): Linear(8.26 k, 0.255% Params, 24.64 KMac, 0.100% MACs, in_features=128, out_features=64, bias=True)
#           (1): h_sigmoid(
#             0, 0.000% Params, 192.0 Mac, 0.001% MACs,
#             (relu): ReLU6(0, 0.000% Params, 192.0 Mac, 0.001% MACs, inplace=True)
#           )
#         )
#         (q): Linear(8.26 k, 0.255% Params, 24.64 KMac, 0.100% MACs, in_features=128, out_features=64, bias=True)
#         (proj): Linear(8.32 k, 0.257% Params, 24.7 KMac, 0.100% MACs, in_features=64, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         98.94 k, 3.061% Params, 296.32 KMac, 1.205% MACs,
#         (ffn): Sequential(
#           65.92 k, 2.039% Params, 197.76 KMac, 0.804% MACs,
#           (0): Linear(33.02 k, 1.022% Params, 98.56 KMac, 0.401% MACs, in_features=128, out_features=256, bias=True)
#           (1): GELU(0, 0.000% Params, 768.0 Mac, 0.003% MACs, approximate=none)
#           (2): Linear(32.9 k, 1.018% Params, 98.43 KMac, 0.400% MACs, in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         24.77 k, 0.766% Params, 73.92 KMac, 0.300% MACs,
#         (k): Linear(12.38 k, 0.383% Params, 36.96 KMac, 0.150% MACs, in_features=128, out_features=96, bias=True)
#         (proj): Linear(12.38 k, 0.383% Params, 36.96 KMac, 0.150% MACs, in_features=128, out_features=96, bias=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#     )
#     (8): DnaBlock(
#       280.51 k, 8.677% Params, 2.3 MMac, 9.346% MACs,
#       (conv1): Sequential(
#         14.98 k, 0.463% Params, 733.82 KMac, 2.983% MACs,
#         (0): Conv2d(13.82 k, 0.428% Params, 677.38 KMac, 2.754% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(1.15 k, 0.036% Params, 56.45 KMac, 0.229% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act1): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper1): HyperFunc(
#         42.14 k, 1.304% Params, 43.33 KMac, 0.176% MACs,
#         (hyper): Sequential(
#           42.14 k, 1.304% Params, 43.33 KMac, 0.176% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(38.02 k, 1.176% Params, 38.02 KMac, 0.155% MACs, in_features=32, out_features=1152, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 1.15 KMac, 0.005% MACs,
#             (relu): ReLU6(0, 0.000% Params, 1.15 KMac, 0.005% MACs, inplace=True)
#           )
#         )
#       )
#       (conv2): Sequential(
#         6.34 k, 0.196% Params, 310.46 KMac, 1.262% MACs,
#         (0): Conv2d(5.18 k, 0.160% Params, 254.02 KMac, 1.033% MACs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (1): BatchNorm2d(1.15 k, 0.036% Params, 56.45 KMac, 0.229% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act2): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper2): HyperFunc(
#         42.14 k, 1.304% Params, 43.33 KMac, 0.176% MACs,
#         (hyper): Sequential(
#           42.14 k, 1.304% Params, 43.33 KMac, 0.176% MACs,
#           (0): Linear(4.13 k, 0.128% Params, 4.13 KMac, 0.017% MACs, in_features=128, out_features=32, bias=True)
#           (1): ReLU(0, 0.000% Params, 32.0 Mac, 0.000% MACs, inplace=True)
#           (2): Linear(38.02 k, 1.176% Params, 38.02 KMac, 0.155% MACs, in_features=32, out_features=1152, bias=True)
#           (3): h_sigmoid(
#             0, 0.000% Params, 1.15 KMac, 0.005% MACs,
#             (relu): ReLU6(0, 0.000% Params, 1.15 KMac, 0.005% MACs, inplace=True)
#           )
#         )
#       )
#       (conv3): Sequential(
#         14.02 k, 0.434% Params, 686.78 KMac, 2.792% MACs,
#         (0): Conv2d(13.82 k, 0.428% Params, 677.38 KMac, 2.754% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#         (1): BatchNorm2d(192, 0.006% Params, 9.41 KMac, 0.038% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act3): DyReLU(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (act): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (hyper3): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       (local_global): Local2Global(
#         37.18 k, 1.150% Params, 111.2 KMac, 0.452% MACs,
#         (alpha): Sequential(
#           12.38 k, 0.383% Params, 37.25 KMac, 0.151% MACs,
#           (0): Linear(12.38 k, 0.383% Params, 36.96 KMac, 0.150% MACs, in_features=128, out_features=96, bias=True)
#           (1): h_sigmoid(
#             0, 0.000% Params, 288.0 Mac, 0.001% MACs,
#             (relu): ReLU6(0, 0.000% Params, 288.0 Mac, 0.001% MACs, inplace=True)
#           )
#         )
#         (q): Linear(12.38 k, 0.383% Params, 36.96 KMac, 0.150% MACs, in_features=128, out_features=96, bias=True)
#         (proj): Linear(12.42 k, 0.384% Params, 36.99 KMac, 0.150% MACs, in_features=96, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_block): GlobalBlock(
#         98.94 k, 3.061% Params, 296.32 KMac, 1.205% MACs,
#         (ffn): Sequential(
#           65.92 k, 2.039% Params, 197.76 KMac, 0.804% MACs,
#           (0): Linear(33.02 k, 1.022% Params, 98.56 KMac, 0.401% MACs, in_features=128, out_features=256, bias=True)
#           (1): GELU(0, 0.000% Params, 768.0 Mac, 0.003% MACs, approximate=none)
#           (2): Linear(32.9 k, 1.018% Params, 98.43 KMac, 0.400% MACs, in_features=256, out_features=128, bias=True)
#         )
#         (ffn_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (q): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (channel_mlp): Linear(16.51 k, 0.511% Params, 49.28 KMac, 0.200% MACs, in_features=128, out_features=128, bias=True)
#         (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#       (global_local): Global2Local(
#         24.77 k, 0.766% Params, 73.92 KMac, 0.300% MACs,
#         (k): Linear(12.38 k, 0.383% Params, 36.96 KMac, 0.150% MACs, in_features=128, out_features=96, bias=True)
#         (proj): Linear(12.38 k, 0.383% Params, 36.96 KMac, 0.150% MACs, in_features=128, out_features=96, bias=True)
#         (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#       )
#     )
#   )
#   (local_global): Local2Global(
#     37.18 k, 1.150% Params, 111.2 KMac, 0.452% MACs,
#     (alpha): Sequential(
#       12.38 k, 0.383% Params, 37.25 KMac, 0.151% MACs,
#       (0): Linear(12.38 k, 0.383% Params, 36.96 KMac, 0.150% MACs, in_features=128, out_features=96, bias=True)
#       (1): h_sigmoid(
#         0, 0.000% Params, 288.0 Mac, 0.001% MACs,
#         (relu): ReLU6(0, 0.000% Params, 288.0 Mac, 0.001% MACs, inplace=True)
#       )
#     )
#     (q): Linear(12.38 k, 0.383% Params, 36.96 KMac, 0.150% MACs, in_features=128, out_features=96, bias=True)
#     (proj): Linear(12.42 k, 0.384% Params, 36.99 KMac, 0.150% MACs, in_features=96, out_features=128, bias=True)
#     (layer_norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (128,), eps=1e-05, elementwise_affine=True)
#     (drop_path): DropPath(0, 0.000% Params, 0.0 Mac, 0.000% MACs, drop_prob=0.000)
#   )
#   (classifier): MergeClassifier(
#     1.76 M, 54.564% Params, 2.54 MMac, 10.329% MACs,
#     (conv): Sequential(
#       14.98 k, 0.463% Params, 733.82 KMac, 2.983% MACs,
#       (0): ChannelShuffle(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (1): Conv2d(13.82 k, 0.428% Params, 677.38 KMac, 2.754% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), groups=4, bias=False)
#       (2): BatchNorm2d(1.15 k, 0.036% Params, 56.45 KMac, 0.229% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act): DyReLU(
#       0, 0.000% Params, 28.22 KMac, 0.115% MACs,
#       (act): ReLU6(0, 0.000% Params, 28.22 KMac, 0.115% MACs, inplace=True)
#     )
#     (hyper): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#     (avgpool): Sequential(
#       0, 0.000% Params, 28.8 KMac, 0.117% MACs,
#       (0): AdaptiveAvgPool2d(0, 0.000% Params, 28.22 KMac, 0.115% MACs, output_size=(1, 1))
#       (1): h_swish(
#         0, 0.000% Params, 576.0 Mac, 0.002% MACs,
#         (sigmoid): h_sigmoid(
#           0, 0.000% Params, 576.0 Mac, 0.002% MACs,
#           (relu): ReLU6(0, 0.000% Params, 576.0 Mac, 0.002% MACs, inplace=True)
#         )
#       )
#     )
#     (fc): Sequential(
#       723.97 k, 22.395% Params, 724.99 KMac, 2.947% MACs,
#       (0): Linear(721.92 k, 22.331% Params, 721.92 KMac, 2.935% MACs, in_features=704, out_features=1024, bias=True)
#       (1): BatchNorm1d(2.05 k, 0.063% Params, 2.05 KMac, 0.008% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         0, 0.000% Params, 1.02 KMac, 0.004% MACs,
#         (sigmoid): h_sigmoid(
#           0, 0.000% Params, 1.02 KMac, 0.004% MACs,
#           (relu): ReLU6(0, 0.000% Params, 1.02 KMac, 0.004% MACs, inplace=True)
#         )
#       )
#     )
#     (classifier): Sequential(
#       1.02 M, 31.706% Params, 1.02 MMac, 4.167% MACs,
#       (0): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#       (1): Linear(1.02 M, 31.706% Params, 1.02 MMac, 4.167% MACs, in_features=1024, out_features=1000, bias=True)
#     )
#   )
# )
# Computational complexity:       24.6 MMac
# Number of parameters:           3.23 M
